# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Experience': [1, 3, 5, 7, 10],
    'Projects': [2, 5, 8, 10, 12],
    'Performance': [3, 6, 7, 8, 9],
    'Department': ['HR', 'IT', 'Sales', 'IT', 'HR']
})

correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# HR mentioned twice
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       3 import matplotlib.pyplot as plt
#       5 data = pd.DataFrame({
#       6     'Experience': [1, 3, 5, 7, 10],
#       7     'Projects': [2, 5, 8, 10, 12],
#       8     'Performance': [3, 6, 7, 8, 9],
#       9     'Department': ['HR', 'IT', 'Sales', 'IT', 'HR']
#      10 })
# ---> 12 correlation_matrix = data.corr()
#      13 sns.heatmap(correlation_matrix, annot=True)
#      14 plt.show()
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/internals/managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/internals/managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'HR'

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'Name': ['John', 'Emily', 'Michael', 'kishor', 'Sarah'],
    'Age': [25, 30, np.nan, 28, 22],
    'Salary': [50000, 60000, 55000, 58000, np.nan]
})

data.fillna(np.mean, inplace=True)
data
#no error
# Out:
# /var/folders/0b/pn0xqpcd7hb0qvhjxrpdhclm0000gn/T/ipykernel_25577/577942251.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<function mean at 0x11153d120>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.fillna(np.mean, inplace=True)
#       Name                             Age                          Salary
# 0     John                            25.0                         50000.0
# 1    Emily                            30.0                         60000.0
# 2  Michael  <function mean at 0x11153d120>                         55000.0
# 3   kishor                            28.0                         58000.0
# 4    Sarah                            22.0  <function mean at 0x11153d120>

# %%
from scipy import stats

group1 = [120, 125, 130, 122, 128]
group2 = [110, 115, 108, 102, 107]

t_stat, p_value = stats.ttest_ind(group1, group2, axis=1)
print(f"T-Statistic: {t_stat}, P-Value: {p_value}")

if p_value <= 0.05:
    print("Reject the null hypothesis: Significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
#axis range issue
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 group1 = [120, 125, 130, 122, 128]
#       4 group2 = [110, 115, 108, 102, 107]
# ----> 6 t_stat, p_value = stats.ttest_ind(group1, group2, axis=1)
#       7 print(f"T-Statistic: {t_stat}, P-Value: {p_value}")
#       9 if p_value <= 0.05:
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/scipy/_lib/deprecation.py:234, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     232 if extra_args <= 0:
#     233     warn_deprecated_args(kwargs)
# --> 234     return f(*args, **kwargs)
#     236 # extra_args > 0
#     237 kwonly_extra_args = set(kwonly_args[:extra_args]) - deprecated_args
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:528, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     525     samples = [np.asarray(sample.ravel()) for sample in samples]
#     526 else:
#     527     # don't ignore any axes when broadcasting if paired
# --> 528     samples = _broadcast_arrays(samples, axis=axis if not paired else None)
#     529     axis = np.atleast_1d(axis)
#     530     n_axes = len(axis)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:51, in _broadcast_arrays(arrays, axis, xp)
#      49 arrays = [xp.asarray(arr) for arr in arrays]
#      50 shapes = [arr.shape for arr in arrays]
# ---> 51 new_shapes = _broadcast_shapes(shapes, axis)
#      52 if axis is None:
#      53     new_shapes = [new_shapes]*len(arrays)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:91, in _broadcast_shapes(shapes, axis)
#      88 if axis[-1] >= n_dims or axis[0] < 0:
#      89     message = (f"`axis` is out of bounds "
#      90                f"for array of dimension {n_dims}")
# ---> 91     raise AxisError(message)
#      93 if len(np.unique(axis)) != len(axis):
#      94     raise AxisError("`axis` must contain only distinct elements")
#
# AxisError: `axis` is out of bounds for array of dimension 1

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({'Salary': [30000, 32000, 34000, 500000, 36000, 37000, 39000, 41000, 42000, 450000]})

outlier_threshold = data['Salary'].mean() + 3 * data['Salary'].std()
outliers = data[data['Salary'] > outlier_threshold]

print("Outliers:", outliers)
#no compilation error
# Out:
# Outliers: Empty DataFrame
# Columns: [Salary]
# Index: []

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = np.random.normal(50, 10, 1000)

plt.hist()
plt.title("PDF Plot")
plt.show()
#need to pass arguments ?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       3 import seaborn as sns
#       5 data = np.random.normal(50, 10, 1000)
# ----> 7 plt.hist()
#       8 plt.title("PDF Plot")
#       9 plt.show()
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: hist() missing 1 required positional argument: 'x'
